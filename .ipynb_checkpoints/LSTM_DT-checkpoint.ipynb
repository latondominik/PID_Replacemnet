# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import time
import pickle
# For LSTM model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.models import load_model

from sklearn.metrics import mean_absolute_error, mean_squared_error, median_absolute_error, mean_absolute_percentage_error, r2_score
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
# Out:
# 2023-08-22 07:42:50.564239: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-22 07:42:50.619756: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-22 07:42:50.621050: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-22 07:42:51.430925: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
# ...

# %%
! pip install pip install optuna
# Out:
# ...
#   Obtaining dependency information for optuna from https://files.pythonhosted.org/packages/69/60/87a06ef66b34cbe2f2eb0ab66f003664404a7f40c21403a69fad7e28a82b/optuna-3.3.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for cmaes>=0.10.0 from https://files.pythonhosted.org/packages/f7/46/7d9544d453346f6c0c405916c95fdb653491ea2e9976cabb810ba2fe8cd4/cmaes-0.10.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.2/404.2 kB 4.8 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# Load training data

DT_1 = pd.read_csv('Data/DT_garnek_1th_try.csv')
DT_2 = pd.read_csv('Data/DT_garnek_1th_try_continue.csv')
DT_3 = pd.read_csv('Data/DT_garnek_1th_try_continue_2.csv')
DT_4 = pd.read_csv('Data/DT_garnek_1th_try_continue_3.csv')

# train = pd.concat([DT_1, DT_2, DT_3])
train = pd.concat([DT_1, DT_2, DT_3, DT_4])

train = train.reset_index()
train['temperature'] = train['temperature'].apply(lambda x: 100 if x > 100 else x)

# %%
train.describe()
# Out:
#               index   temperature       control
# count  11621.000000  11621.000000  11621.000000
# mean    2030.643834     67.822452     30.212288
# std     1571.703863     22.946427     30.574146
# min        0.000000     20.540638      0.000000
# 25%      726.000000     54.436995      0.000000
# 50%     1594.000000     71.361797     20.000000
# 75%     3046.000000     86.650223     42.000000
# max     5758.000000    100.000000    100.000000

# %%
train.head(5)
# Out:
#    index  temperature  control
# 0      0    23.112085     71.0
# 1      1    21.569217     71.0
# 2      2    21.896492     71.0
# 3      3    22.551042     71.0
# 4      4    20.540638     71.0

# %%
fig = make_subplots(rows=2, cols = 1)

fig.add_trace(
    go.Scatter(y=train["temperature"], name="Temperature "), row=1, col=1
)

fig.add_trace(
    go.Scatter(y=train["control"], name="Control Variable [%]"), row=2, col=1
)

fig.update_layout(height=700, width=1100)
fig.show()
# Out:
# <div>                            <div id="49b5781a-8ba3-48ee-bd9c-46a75e811539" class="plotly-graph-div" style="height:700px; width:1100px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49b5781a-8ba3-48ee-bd9c-46a75e811539")) {                    Plotly.newPlot(                        "49b5781a-8ba3-48ee-bd9c-46a75e811539",                        [{"name":"Temperature ","y":[23.112085349053277,21.56921667254029,21.896491846346077,22.55104219395764,20.54063755486495,22.03675263511997,20.82115913241277,23.532867715375,23.71988210040688,20.63414474738089,23.62637490789093,23.673128504148902,25.49651875820972,23.299099734085157,25.636779546983625,23.065331752795306,26.665358664658957,25.2159971806619,26.57185147214301,26.10431550956332,29.517328036395085,27.039387434722716,29.7978496139429,27.600430589818338
# ...

# %%
window_to_avg = 10
train['smooth_temperature'] = train['temperature'].rolling(window_to_avg).sum()/window_to_avg
# train['smooth_temperature'] = train['temperature']

# %%
fig = make_subplots(rows=2, cols = 1)

fig.add_trace(
    go.Scatter(y=train["temperature"], name="Measured"), row=1, col=1
)

fig.add_trace(
    go.Scatter(y=train["smooth_temperature"], name="Average"), row=2, col=1
)



fig.update_layout(height=700, width=1100)
fig.show()
# Out:
# <div>                            <div id="667011e5-6d9d-45c0-b281-b28b3c1ef705" class="plotly-graph-div" style="height:700px; width:1100px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("667011e5-6d9d-45c0-b281-b28b3c1ef705")) {                    Plotly.newPlot(                        "667011e5-6d9d-45c0-b281-b28b3c1ef705",                        [{"name":"Measured","y":[23.112085349053277,21.56921667254029,21.896491846346077,22.55104219395764,20.54063755486495,22.03675263511997,20.82115913241277,23.532867715375,23.71988210040688,20.63414474738089,23.62637490789093,23.673128504148902,25.49651875820972,23.299099734085157,25.636779546983625,23.065331752795306,26.665358664658957,25.2159971806619,26.57185147214301,26.10431550956332,29.517328036395085,27.039387434722716,29.7978496139429,27.600430589818338,28.
# ...

# %%
# Scale features
s1 = MinMaxScaler(feature_range=(-1,1))
Xs = s1.fit_transform(train[['smooth_temperature','control']])

# Scale predicted value
s2 = MinMaxScaler(feature_range=(-1,1))
Ys = s2.fit_transform(train[['smooth_temperature']])

# %%
pickle.dump(s1, open('input_scaler.sav', 'wb'))
pickle.dump(s2, open('output_scaler.sav', 'wb'))

# %%
# Each time step uses last 'window' to predict the next change
window = 30
X = []
Y = []
for i in range(window,len(Xs)):
    X.append(Xs[i-window:i,:])
    Y.append(Ys[i])

# Reshape data to format accepted by LSTM
X, Y = np.array(X), np.array(Y)
X = X[window:]
Y = Y[window:]
# create and train LSTM model

# Initialize LSTM model
model = Sequential()

model.add(LSTM(units=40, return_sequences=True, \
          input_shape=(X.shape[1],X.shape[2])))
model.add(Dropout(0.4))
model.add(LSTM(units=40, return_sequences=True))
model.add(Dropout(0.4))
model.add(LSTM(units=40))
model.add(Dropout(0.4))
model.add(Dense(units=1))
model.compile(optimizer = 'adam', loss = 'mean_squared_error',
              metrics = ['accuracy'])

# Allow for early exit
es = EarlyStopping(monitor='loss',mode='min',verbose=1,patience=10)

# %%
# Fit (and time) LSTM model
t0 = time.time()
history = model.fit(X, Y, epochs = 20, batch_size = 360, callbacks=[es], verbose=1)
t1 = time.time()
print('Runtime: %.2f s' %(t1-t0))

# %%
# Plot loss
plt.figure(figsize=(8,4))
plt.semilogy(history.history['loss'])
plt.xlabel('epoch'); plt.ylabel('loss')
plt.savefig('tclab_loss.png')
model.save('model_6.keras')

# %%
# Verify the fit of the model
Yp = model.predict(X)

# un-scale outputs
Yu = s2.inverse_transform(Yp)
Ym = s2.inverse_transform(Y)

plt.figure(figsize=(10,6))
plt.subplot(2,1,1)
plt.plot(Yu,'r-',label='LSTM')
plt.plot(Ym,'k--',label='Measured')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.subplot(2,1,2)
plt.plot(train['control'],label='heater (%)')
plt.legend()
plt.xlabel('Time (sec)'); plt.ylabel('Heater')
# plt.savefig('garnek_fit.png')
plt.show()

# %%
# Load model
model = load_model('model_git.keras')
window = 30
window_to_avg = 10
# Load training data
# test = pd.read_csv('PID_garnek_6th_try_en.csv')
test = pd.read_csv('DT_garnek_2th_try.csv')
test.drop(index = 0, inplace= True)
test['temperature'] = test['temperature'].apply(lambda x: 100 if x > 100 else x)
test['smooth_temperature'] = test['temperature'].rolling(window_to_avg).sum()/window_to_avg
test['control'] = test['control'].rolling(window_to_avg).sum()/window_to_avg
# test['smooth_temperature'] = test['temperature']
Xt = test[['smooth_temperature','control']].values
Yt = test[['smooth_temperature']].values

Xts = s1.transform(Xt)
Yts = s2.transform(Yt)


Xts = Xts[window:]
Yts = Yts[window:]

Xti = []
Yti = []
for i in range(window,len(Xts)):
    Xti.append(Xts[i-window:i,:])
    Yti.append(Yts[i])

# Reshape data to format accepted by LSTM
Xti, Yti = np.array(Xti), np.array(Yti)
# Out:
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning:
#
# X does not have valid feature names, but MinMaxScaler was fitted with feature names
#
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning:
#
# X does not have valid feature names, but MinMaxScaler was fitted with feature names

# %%
# Verify the fit of the model
Ytp = model.predict(Xti)
# un-scale outputs
Ytu = s2.inverse_transform(Ytp)
Ytm = s2.inverse_transform(Yti)
# Out:
# 111/111 [==============================] - 2s 7ms/step

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,1,1)
plt.plot(Ytu,'r-',label='LSTM Predicted')
plt.plot(Ytm,'k--',label='Measured')
plt.legend()
plt.ylabel('Temperature (°C)')
plt.subplot(2,1,2)
# plt.plot(Ytm,'k--',label='Measured')
plt.plot(test['control'],'b-',label='Heater')
plt.xlabel('Time (sec)'); plt.ylabel('Heater (%)')
plt.legend()
plt.show()

# %%
# Using predicted values to predict next step

Xtsq = Xts.copy()
for i in range(window,len(Xtsq)):
    Xin = Xtsq[i-window:i].reshape((1, window, 2))
    Xtsq[i][0] = model.predict(Xin)
    Yti[i-window] = Xtsq[i][0]

#Ytu = (Yti - s2.min_[0])/s2.scale_[0]
Ytu = s2.inverse_transform(Yti)
# Out:
# ...
# 1/1 [==============================] - 0s 16ms/step
# ...
# ...
# 1/1 [==============================] - 0s 15ms/step

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,1,1)
plt.plot(Ytu,'r-',label='LSTM Predicted')
plt.plot(Ytm,'k--',label='Measured')
plt.legend()
plt.ylabel('Temperature (°C)')
plt.subplot(2,1,2)
plt.plot(test['control'][window:],'b-',label='Heater')
plt.xlabel('Sample'); plt.ylabel('Heater (%)')
plt.legend()
plt.savefig('garnek_forecast.png')
plt.show()

# %%
Ytm_m = []
Ytu_m = []

for i in range(len(Ytu)):
    Ytm_m.append(Ytm[i][0])
    Ytu_m.append(Ytu[i][0])
    
a = mean_absolute_error(Ytu_m, Ytm_m)
b = mean_squared_error(Ytu_m, Ytm_m,  squared=True)
c = mean_squared_error(Ytu_m, Ytm_m,  squared=False)
d = median_absolute_error(Ytu_m, Ytm_m)
e = mean_absolute_percentage_error(Ytu_m, Ytm_m)
f = r2_score(Ytu_m, Ytm_m)

print("mean_absolute_error = ", a, 
      "mean_squared_error = ", b, 
      "root_mean_squared_error = ", c, 
      "median_absolute_error = ", d,
      "mean_absolute_percentage_error = ", e, 
      "r2_score = ", f)
# Out:
# mean_absolute_error =  3.5127584859777925 mean_squared_error =  17.84263926607142 root_mean_squared_error =  4.2240548370104545 median_absolute_error =  3.22859558379497 mean_absolute_percentage_error =  0.04181190502881825 r2_score =  0.863471624891076

# %%
# Load model
model = load_model('model_git.keras')
window = 30
window_to_avg = 10
# Load training data
test = pd.read_csv('PID_garnek_6th_try_en.csv')
# test = pd.read_csv('DT_garnek_2th_try.csv')
test.drop(index = 0, inplace= True)
test['temperature'] = test['temperature'].apply(lambda x: 100 if x > 100 else x)
test['smooth_temperature'] = test['temperature'].rolling(window_to_avg).sum()/window_to_avg
test['control'] = test['control'].rolling(window_to_avg).sum()/window_to_avg
# test['smooth_temperature'] = test['temperature']
Xt = test[['smooth_temperature','control']].values
Yt = test[['smooth_temperature']].values

Xts = s1.transform(Xt)
Yts = s2.transform(Yt)


Xts = Xts[window:]
Yts = Yts[window:]

Xti = []
Yti = []
for i in range(window,len(Xts)):
    Xti.append(Xts[i-window:i,:])
    Yti.append(Yts[i])

# Reshape data to format accepted by LSTM
Xti, Yti = np.array(Xti), np.array(Yti)
# Out:
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning:
#
# X does not have valid feature names, but MinMaxScaler was fitted with feature names
#
# /opt/conda/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning:
#
# X does not have valid feature names, but MinMaxScaler was fitted with feature names

# %%
# Verify the fit of the model
Ytp = model.predict(Xti)
# un-scale outputs
Ytu = s2.inverse_transform(Ytp)
Ytm = s2.inverse_transform(Yti)
# Out:
# 77/77 [==============================] - 1s 7ms/step

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,1,1)
plt.plot(Ytu,'r-',label='LSTM Predicted')
plt.plot(Ytm,'k--',label='Measured')
plt.legend()
plt.ylabel('Temperature (°C)')
plt.subplot(2,1,2)
# plt.plot(Ytm,'k--',label='Measured')
plt.plot(test['control'],'b-',label='Heater')
plt.xlabel('Sample'); plt.ylabel('Heater (%)')
plt.legend()
plt.show()

# %%
# Using predicted values to predict next step

Xtsq = Xts.copy()
for i in range(window,len(Xtsq)):
    Xin = Xtsq[i-window:i].reshape((1, window, 2))
    Xtsq[i][0] = model.predict(Xin)
    Yti[i-window] = Xtsq[i][0]

Ytu = s2.inverse_transform(Yti)
# Out:
# ...
# 1/1 [==============================] - 0s 14ms/step
# ...
# ...
# 1/1 [==============================] - 0s 16ms/step

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,1,1)
plt.plot(Ytu,'r-',label='LSTM Predicted')
plt.plot(Ytm,'k--',label='Measured')
plt.legend()
plt.ylabel('Temperature (°C)')
plt.subplot(2,1,2)
plt.plot(test['control'][window:],'b-',label='Heater')
plt.xlabel('Sample'); plt.ylabel('Heater (%)')
plt.legend()
plt.savefig('garnek_forecast.png')
plt.show()

# %%
Ytm_m = []
Ytu_m = []

for i in range(len(Ytu)):
    Ytm_m.append(Ytm[i][0])
    Ytu_m.append(Ytu[i][0])
    
a = mean_absolute_error(Ytu_m, Ytm_m)
b = mean_squared_error(Ytu_m, Ytm_m,  squared=True)
c = mean_squared_error(Ytu_m, Ytm_m,  squared=False)
d = median_absolute_error(Ytu_m, Ytm_m)
e = mean_absolute_percentage_error(Ytu_m, Ytm_m)
f = r2_score(Ytu_m, Ytm_m)

print("mean_absolute_error = ", a, 
      "mean_squared_error = ", b, 
      "root_mean_squared_error = ", c, 
      "median_absolute_error = ", d,
      "mean_absolute_percentage_error = ", e, 
      "r2_score = ", f)
# Out:
# mean_absolute_error =  1.6014618508833984 mean_squared_error =  5.654074391549962 root_mean_squared_error =  2.377829765048365 median_absolute_error =  0.6788729832116687 mean_absolute_percentage_error =  0.02926664845306414 r2_score =  0.5375706558142637
